# %%
from hdimvis.data_fetchers.DataFetcher import DataFetcher

# %%
globe = DataFetcher.fetch_data('globe')
# Out:
# ####################
# Fetching the "globe" dataset
# ####################
# Dataset loaded
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 globe = DataFetcher.fetch_data('globe')
#
# File ~\Desktop\2095736w\hdimvis\data_fetchers\DataFetcher.py:62, in DataFetcher.fetch_data(dataset_name, for_bhtsne, **kwargs)
#      60 print("#" * 20)
#      61 print("Dataset loaded")
# ---> 62 print(f"Dataset shape: {data.shape[0], data.shape[1]}")
#      63 print("#" * 20)
#      64 return Dataset(data, labels, dataset_name)
#
# IndexError: tuple index out of range
