# %%
from hdimvis.data_fetchers.DataFetcher import DataFetcher
from hdimvis.metrics.distance_measures.euclidian_and_manhattan import manhattan,euclidean
from hdimvis.algorithms.spring_force_algos.chalmers96_algo.Chalmers96 import Chalmers96
from hdimvis.create_low_d_layout.LayoutCreation import LayoutCreation
from hdimvis.visualise_layouts_and_metrics.plot import show_layout, show_generation_metrics
from sklearn.decomposition import PCA
from time import perf_counter
import numpy as np
from pathlib import Path
from definitions import PROJECT_ROOT
import pickle

# %%
rna = DataFetcher.fetch_data('rna N3k')
coli20 =  DataFetcher.fetch_data('coil20')
mnist = DataFetcher.fetch_data('mnist', size=7000)
globe = DataFetcher.fetch_data('globe', size=100)
# Out:
# ####################
# Fetching the "rna N3k" dataset
# ####################
# Dataset loaded
# Dataset shape: (3000, 50)
# ####################
# ####################
# Fetching the "coil20" dataset
# ####################
# Dataset loaded
# Dataset shape: (1440, 1024)
# ####################
# ####################
# Fetching the "mnist" dataset
# C:\Users\Owner\.virtualenvs\2095736w-0SnFieZ0\lib\site-packages\sklearn\datasets\_openml.py:932: FutureWarning: The default value of `parser` will change from `'liac-arff'` to `'auto'` in 1.4. You can set `parser='auto'` to silence this warning. Therefore, an `ImportError` will be raised from 1.4 if the dataset is dense and pandas is not installed. Note that the pandas parser may return different data types. See the Notes Section in fetch_openml's API doc for details.
#   warn(
# ####################
# Dataset loaded
# Dataset shape: (7000, 784)
# ####################
# ####################
# Fetching the "globe" dataset
# ####################
# Dataset loaded
# Dataset shape: (102, 3)
# ####################

# %%
rna = DataFetcher.fetch_data('rna N3k')
datasets = [rna]
dataset_names = ['rna N3k']
# datasets =[globe]
# dataset_names = ['globe']

# %%
max = 20
num_repeats = 3
results = {dataset_name : (np.zeros((max,max,num_repeats)),
                           [[[None for k in range(num_repeats)] for j in range(max)] for i in range(max)])
           for dataset_name in dataset_names }

for i,dataset in enumerate(datasets):
    n_neigh = 1
    n_sample = 1
    while n_neigh <= max:
        while n_sample <= max:
            print(f" n sample: {n_sample}")
            print(f" n_neigh {n_neigh}")

            for j in range(num_repeats):
                print(f" n sample -1: {n_sample - 1}")
                print(f" n_neigh -1  {n_neigh -1 }")
                algo96 = Chalmers96(dataset=dataset, distance_fn=euclidean,
                                damping_constant=0, spring_constant=0.5,
                                use_knnd=False, sample_set_size=n_neigh, neighbour_set_size=n_sample)
                start = perf_counter()
                layout = LayoutCreation.create_layout(algo96, no_iters=100)
                results[dataset_names[i]][0][n_neigh-1, n_sample-1, j] = perf_counter() - start
                results[dataset_names[i]][1][n_neigh-1][ n_sample-1][ j] = layout
            n_sample += 1
        n_sample = 1
        n_neigh += 1


output_dir= (Path(PROJECT_ROOT).joinpath(
    Path(f"experiments/varing_V_and_S/out/"))).resolve().absolute()

path_to_pickle = (Path(output_dir).joinpath(Path(f"results_rna.pickle"))).resolve()
with open(path_to_pickle, 'wb') as pickle_out:
    pickle.dump(results, pickle_out)
# Out:
#  n sample: 1
#  n_neigh 1
#  n sample -1: 0
#  n_neigh -1  0
# ####################
# The algorithm will use a random initialization for the low D embedding/layout
# ####################
# A 2D layout of the "rna N3k" dataset will be created
# using the "Chalmers' 1996" algorithm
# ####################
# The HD distance measure used is: euclidean
# ####################
# ####################
# No metrics will be collected during layout creation.
# To change this use the 'metric collection' parameter of the layout
# ####################
# All stress calculations will be performed using the euclidian norm
# ####################
# Spring constant is set to  0.5
# Damping constant is set to 0
# Spring constant scaling factor is set to 0.25
# ####################
#  n sample -1: 0
#  n_neigh -1  0
# ####################
# The algorithm will use a random initialization for the low D embedding/layout
# ####################
# A 2D layout of the "rna N3k" dataset will be created
# using the "Chalmers' 1996" algorithm
# ####################
# The HD distance measure used is: euclidean
# ####################
# ####################
# No metrics will be collected during layout creation.
# To change this use the 'metric collection' parameter of the layout
# ####################
# All stress calculations will be performed using the euclidian norm
# ####################
# Spring constant is set to  0.5
# Damping constant is set to 0
# Spring constant scaling factor is set to 0.25
# ####################
#  n sample -1: 0
#  n_neigh -1  0
# ####################
# The algorithm will use a random initialization for the low D embedding/layout
# ####################
# A 2D layout of the "rna N3k" dataset will be created
# using the "Chalmers' 1996" algorithm
# ####################
# The HD distance measure used is: euclidean
# ####################
# ####################
# No metrics will be collected during layout creation.
# To change this use the 'metric collection' parameter of the layout
# ####################
# All stress calculations will be performed using the euclidian norm
# ####################
# Spring constant is set to  0.5
# Damping constant is set to 0
# Spring constant scaling factor is set to 0.25
# ####################
#  n sample: 2
#  n_neigh 1
#  n sample -1: 1
#  n_neigh -1  0
# ####################
# The algorithm will use a random initialization for the low D embedding/layout
# ####################
# A 2D layout of the "rna N3k" dataset will be created
# using the "Chalmers' 1996" algorithm
# ####################
# The HD distance measure used is: euclidean
# ####################
# ####################
# No metrics will be collected during layout creation.
# To change this use the 'metric collection' parameter of the layout
# ####################
# All stress calculations will be performed using the euclidian norm
# ####################
# Spring constant is set to  0.5
# Damping constant is set to 0
# Spring constant scaling factor is set to 0.16666666666666666
# ####################
#  n sample -1: 1
#  n_neigh -1  0
# ####################
# The algorithm will use a random initialization for the low D embedding/layout
# ####################
# A 2D layout of the "rna N3k" dataset will be created
# using the "Chalmers' 1996" algorithm
# ####################
# The HD distance measure used is: euclidean
# ####################
# ####################
# No metrics will be collected during layout creation.
# To change this use the 'metric collection' parameter of the layout
# ####################
# All stress calculations will be performed using the euclidian norm
# ####################
# Spring constant is set to  0.5
# Damping constant is set to 0
# Spring constant scaling factor is set to 0.16666666666666666
# ####################
#  n sample -1: 1
#  n_neigh -1  0
# ####################
# The algorithm will use a random initialization for the low D embedding/layout
# ####################
# A 2D layout of the "rna N3k" dataset will be created
# using the "Chalmers' 1996" algorithm
# ####################
# The HD distance measure used is: euclidean
# ####################
# ####################
# No metrics will be collected during layout creation.
# To change this use the 'metric collection' parameter of the layout
# ####################
# All stress calculations will be performed using the euclidian norm
# ####################
# Spring constant is set to  0.5
# Damping constant is set to 0
# Spring constant scaling factor is set to 0.16666666666666666
# ####################
#  n sample: 3
#  n_neigh 1
#  n sample -1: 2
#  n_neigh -1  0
# ####################
# The algorithm will use a random initialization for the low D embedding/layout
# ####################
# A 2D layout of the "rna N3k" dataset will be created
# using the "Chalmers' 1996" algorithm
# ####################
# The HD distance measure used is: euclidean
# ####################
# ####################
# No metrics will be collected during layout creation.
# To change this use the 'metric collection' parameter of the layout
# ####################
# All stress calculations will be performed using the euclidian norm
# ####################
# Spring constant is set to  0.5
# Damping constant is set to 0
# Spring constant scaling factor is set to 0.125
# ####################
#  n sample -1: 2
#  n_neigh -1  0
# ####################
# The algorithm will use a random initialization for the low D embedding/layout
# ####################
# A 2D layout of the "rna N3k" dataset will be created
# using the "Chalmers' 1996" algorithm
# ####################
# The HD distance measure used is: euclidean
# ####################
# ####################
# No metrics will be collected during layout creation.
# To change this use the 'metric collection' parameter of the layout
# ####################
# All stress calculations will be performed using the euclidian norm
# ####################
# Spring constant is set to  0.5
# Damping constant is set to 0
# Spring constant scaling factor is set to 0.125
# ####################
#  n sample -1: 2
#  n_neigh -1  0
# ####################
# The algorithm will use a random initialization for the low D embedding/layout
# ####################
# A 2D layout of the "rna N3k" dataset will be created
# using the "Chalmers' 1996" algorithm
# ####################
# The HD distance measure used is: euclidean
# ####################
# ####################
# No metrics will be collected during layout creation.
# To change this use the 'metric collection' parameter of the layout
# ####################
# All stress calculations will be performed using the euclidian norm
# ####################
# Spring constant is set to  0.5
# Damping constant is set to 0
# Spring constant scaling factor is set to 0.125
# ####################
#  n sample: 4
#  n_neigh 1
#  n sample -1: 3
#  n_neigh -1  0
# ####################
# The algorithm will use a random initialization for the low D embedding/layout
# ####################
# A 2D layout of the "rna N3k" dataset will be created
# using the "Chalmers' 1996" algorithm
# ####################
# The HD distance measure used is: euclidean
# ####################
# ####################
# No metrics will be collected during layout creation.
# To change this use the 'metric collection' parameter of the layout
# ####################
# All stress calculations will be performed using the euclidian norm
# ####################
# Spring constant is set to  0.5
# Damping constant is set to 0
# Spring constant scaling factor is set to 0.1
# ####################
#  n sample -1: 3
#  n_neigh -1  0
# ####################
# The algorithm will use a random initialization for the low D embedding/layout
# ####################
# A 2D layout of the "rna N3k" dataset will be created
# using the "Chalmers' 1996" algorithm
# ####################
# The HD distance measure used is: euclidean
# ####################
# ####################
# No metrics will be collected during layout creation.
# To change this use the 'metric collection' parameter of the layout
# ####################
# All stress calculations will be performed using the euclidian norm
# ####################
# Spring constant is set to  0.5
# Damping constant is set to 0
# Spring constant scaling factor is set to 0.1
# ####################
#  n sample -1: 3
#  n_neigh -1  0
# ####################
# The algorithm will use a random initialization for the low D embedding/layout
# ####################
# A 2D layout of the "rna N3k" dataset will be created
# using the "Chalmers' 1996" algorithm
# ####################
# The HD distance measure used is: euclidean
# ####################
# ####################
# No metrics will be collected during layout creation.
# To change this use the 'metric collection' parameter of the layout
# ####################
# All stress calculations will be performed using the euclidian norm
# ####################
# Spring constant is set to  0.5
# Damping constant is set to 0
# Spring constant scaling factor is set to 0.1
# ####################
#  n sample: 5
#  n_neigh 1
#  n sample -1: 4
#  n_neigh -1  0
# ####################
# The algorithm will use a random initialization for the low D embedding/layout
# ####################
# A 2D layout of the "rna N3k" dataset will be created
# using the "Chalmers' 1996" algorithm
# ####################
# The HD distance measure used is: euclidean
# ####################
# ####################
# No metrics will be collected during layout creation.
# To change this use the 'metric collection' parameter of the layout
# ####################
# All stress calculations will be performed using the euclidian norm
# ####################
# Spring constant is set to  0.5
# Damping constant is set to 0
# Spring constant scaling factor is set to 0.08333333333333333
# ####################
#  n sample -1: 4
#  n_neigh -1  0
# ####################
# The algorithm will use a random initialization for the low D embedding/layout
# ####################
# A 2D layout of the "rna N3k" dataset will be created
# using the "Chalmers' 1996" algorithm
# ####################
# The HD distance measure used is: euclidean
# ####################
# ####################
# No metrics will be collected during layout creation.
# To change this use the 'metric collection' parameter of the layout
# ####################
# All stress calculations will be performed using the euclidian norm
# ####################
# Spring constant is set to  0.5
# Damping constant is set to 0
# Spring constant scaling factor is set to 0.08333333333333333
# ####################
#  n sample -1: 4
#  n_neigh -1  0
# ####################
# The algorithm will use a random initialization for the low D embedding/layout
# ####################
# A 2D layout of the "rna N3k" dataset will be created
# using the "Chalmers' 1996" algorithm
# ####################
# The HD distance measure used is: euclidean
# ####################
# ####################
# No metrics will be collected during layout creation.
# To change this use the 'metric collection' parameter of the layout
# ####################
# All stress calculations will be performed using the euclidian norm
# ####################
# Spring constant is set to  0.5
# Damping constant is set to 0
# Spring constant scaling factor is set to 0.08333333333333333
# ####################
#  n sample: 6
#  n_neigh 1
#  n sample -1: 5
#  n_neigh -1  0
# ####################
# The algorithm will use a random initialization for the low D embedding/layout
# ####################
# A 2D layout of the "rna N3k" dataset will be created
# using the "Chalmers' 1996" algorithm
# ####################
# The HD distance measure used is: euclidean
# ####################
# ####################
# No metrics will be collected during layout creation.
# To change this use the 'metric collection' parameter of the layout
# ####################
# All stress calculations will be performed using the euclidian norm
# ####################
# Spring constant is set to  0.5
# Damping constant is set to 0
# Spring constant scaling factor is set to 0.07142857142857142
# ####################
#  n sample -1: 5
#  n_neigh -1  0
# ####################
# The algorithm will use a random initialization for the low D embedding/layout
# ####################
# A 2D layout of the "rna N3k" dataset will be created
# using the "Chalmers' 1996" algorithm
# ####################
# The HD distance measure used is: euclidean
# ####################
# ####################
# No metrics will be collected during layout creation.
# To change this use the 'metric collection' parameter of the layout
# ####################
# All stress calculations will be performed using the euclidian norm
# ####################
# Spring constant is set to  0.5
# Damping constant is set to 0
# Spring constant scaling factor is set to 0.07142857142857142
# ####################
#  n sample -1: 5
#  n_neigh -1  0
# ####################
# The algorithm will use a random initialization for the low D embedding/layout
# ####################
# A 2D layout of the "rna N3k" dataset will be created
# using the "Chalmers' 1996" algorithm
# ####################
# The HD distance measure used is: euclidean
# ####################
# ####################
# No metrics will be collected during layout creation.
# To change this use the 'metric collection' parameter of the layout
# ####################
# All stress calculations will be performed using the euclidian norm
# ####################
# Spring constant is set to  0.5
# Damping constant is set to 0
# Spring constant scaling factor is set to 0.07142857142857142
# ####################
#  n sample: 7
#  n_neigh 1
#  n sample -1: 6
#  n_neigh -1  0
# ####################
# The algorithm will use a random initialization for the low D embedding/layout
# ####################
# A 2D layout of the "rna N3k" dataset will be created
# using the "Chalmers' 1996" algorithm
# ####################
# The HD distance measure used is: euclidean
# ####################
# ####################
# No metrics will be collected during layout creation.
# To change this use the 'metric collection' parameter of the layout
# ####################
# All stress calculations will be performed using the euclidian norm
# ####################
# Spring constant is set to  0.5
# Damping constant is set to 0
# Spring constant scaling factor is set to 0.0625
# ####################
#  n sample -1: 6
#  n_neigh -1  0
# ####################
# The algorithm will use a random initialization for the low D embedding/layout
# ####################
# A 2D layout of the "rna N3k" dataset will be created
# using the "Chalmers' 1996" algorithm
# ####################
# The HD distance measure used is: euclidean
# ####################
# ####################
# No metrics will be collected during layout creation.
# To change this use the 'metric collection' parameter of the layout
# ####################
# All stress calculations will be performed using the euclidian norm
# ####################
# Spring constant is set to  0.5
# Damping constant is set to 0
# Spring constant scaling factor is set to 0.0625
# ####################
#  n sample -1: 6
#  n_neigh -1  0
# ####################
# The algorithm will use a random initialization for the low D embedding/layout
# ####################
# A 2D layout of the "rna N3k" dataset will be created
# using the "Chalmers' 1996" algorithm
# ####################
# The HD distance measure used is: euclidean
# ####################
# ####################
# No metrics will be collected during layout creation.
# To change this use the 'metric collection' parameter of the layout
# ####################
# All stress calculations will be performed using the euclidian norm
# ####################
# Spring constant is set to  0.5
# Damping constant is set to 0
# Spring constant scaling factor is set to 0.0625
# ####################
#  n sample: 8
#  n_neigh 1
#  n sample -1: 7
#  n_neigh -1  0
# ####################
# The algorithm will use a random initialization for the low D embedding/layout
# ####################
# A 2D layout of the "rna N3k" dataset will be created
# using the "Chalmers' 1996" algorithm
# ####################
# The HD distance measure used is: euclidean
# ####################
# ####################
# No metrics will be collected during layout creation.
# To change this use the 'metric collection' parameter of the layout
# ####################
# All stress calculations will be performed using the euclidian norm
# ####################
# Spring constant is set to  0.5
# Damping constant is set to 0
# Spring constant scaling factor is set to 0.05555555555555555
# ####################
#  n sample -1: 7
#  n_neigh -1  0
# ####################
# The algorithm will use a random initialization for the low D embedding/layout
# ####################
# A 2D layout of the "rna N3k" dataset will be created
# using the "Chalmers' 1996" algorithm
# ####################
# The HD distance measure used is: euclidean
# ####################
# ####################
# No metrics will be collected during layout creation.
# To change this use the 'metric collection' parameter of the layout
# ####################
# All stress calculations will be performed using the euclidian norm
# ####################
# Spring constant is set to  0.5
# Damping constant is set to 0
# Spring constant scaling factor is set to 0.05555555555555555
# ####################
#  n sample -1: 7
#  n_neigh -1  0
# ####################
# The algorithm will use a random initialization for the low D embedding/layout
# ####################
# A 2D layout of the "rna N3k" dataset will be created
# using the "Chalmers' 1996" algorithm
# ####################
# The HD distance measure used is: euclidean
# ####################
# ####################
# No metrics will be collected during layout creation.
# To change this use the 'metric collection' parameter of the layout
# ####################
# All stress calculations will be performed using the euclidian norm
# ####################
# Spring constant is set to  0.5
# Damping constant is set to 0
# Spring constant scaling factor is set to 0.05555555555555555
# ####################
#  n sample: 9
#  n_neigh 1
#  n sample -1: 8
#  n_neigh -1  0
# ####################
# The algorithm will use a random initialization for the low D embedding/layout
# ####################
# A 2D layout of the "rna N3k" dataset will be created
# using the "Chalmers' 1996" algorithm
# ####################
# The HD distance measure used is: euclidean
# ####################
# ####################
# No metrics will be collected during layout creation.
# To change this use the 'metric collection' parameter of the layout
# ####################
# All stress calculations will be performed using the euclidian norm
# ####################
# Spring constant is set to  0.5
# Damping constant is set to 0
# Spring constant scaling factor is set to 0.05
# ####################
#  n sample -1: 8
#  n_neigh -1  0
# ####################
# The algorithm will use a random initialization for the low D embedding/layout
# ####################
# A 2D layout of the "rna N3k" dataset will be created
# using the "Chalmers' 1996" algorithm
# ####################
# The HD distance measure used is: euclidean
# ####################
# ####################
# No metrics will be collected during layout creation.
# To change this use the 'metric collection' parameter of the layout
# ####################
# All stress calculations will be performed using the euclidian norm
# ####################
# Spring constant is set to  0.5
# Damping constant is set to 0
# Spring constant scaling factor is set to 0.05
# ####################
#  n sample -1: 8
#  n_neigh -1  0
# ####################
# The algorithm will use a random initialization for the low D embedding/layout
# ####################
# A 2D layout of the "rna N3k" dataset will be created
# using the "Chalmers' 1996" algorithm
# ####################
# The HD distance measure used is: euclidean
# ####################
# ####################
# No metrics will be collected during layout creation.
# To change this use the 'metric collection' parameter of the layout
# ####################
# All stress calculations will be performed using the euclidian norm
# ####################
# Spring constant is set to  0.5
# Damping constant is set to 0
# Spring constant scaling factor is set to 0.05
# ####################
#  n sample: 10
#  n_neigh 1
#  n sample -1: 9
#  n_neigh -1  0
# ####################
# The algorithm will use a random initialization for the low D embedding/layout
# ####################
# A 2D layout of the "rna N3k" dataset will be created
# using the "Chalmers' 1996" algorithm
# ####################
# The HD distance measure used is: euclidean
# ####################
# ####################
# No metrics will be collected during layout creation.
# To change this use the 'metric collection' parameter of the layout
# ####################
# All stress calculations will be performed using the euclidian norm
# ####################
# Spring constant is set to  0.5
# Damping constant is set to 0
# Spring constant scaling factor is set to 0.045454545454545456
# ####################
#  n sample -1: 9
#  n_neigh -1  0
# ####################
# The algorithm will use a random initialization for the low D embedding/layout
# ####################
# A 2D layout of the "rna N3k" dataset will be created
# using the "Chalmers' 1996" algorithm
# ####################
# The HD distance measure used is: euclidean
# ####################
# ####################
# No metrics will be collected during layout creation.
# To change this use the 'metric collection' parameter of the layout
# ####################
# All stress calculations will be performed using the euclidian norm
# ####################
# Spring constant is set to  0.5
# Damping constant is set to 0
# Spring constant scaling factor is set to 0.045454545454545456
# ####################
#  n sample -1: 9
#  n_neigh -1  0
# ####################
# The algorithm will use a random initialization for the low D embedding/layout
# ####################
# A 2D layout of the "rna N3k" dataset will be created
# using the "Chalmers' 1996" algorithm
# ####################
# The HD distance measure used is: euclidean
# ####################
# ####################
# No metrics will be collected during layout creation.
# To change this use the 'metric collection' parameter of the layout
# ####################
# All stress calculations will be performed using the euclidian norm
# ####################
# Spring constant is set to  0.5
# Damping constant is set to 0
# Spring constant scaling factor is set to 0.045454545454545456
# ####################
#  n sample: 11
#  n_neigh 1
#  n sample -1: 10
#  n_neigh -1  0
# ####################
# The algorithm will use a random initialization for the low D embedding/layout
# ####################
# A 2D layout of the "rna N3k" dataset will be created
# using the "Chalmers' 1996" algorithm
# ####################
# The HD distance measure used is: euclidean
# ####################
# ####################
# No metrics will be collected during layout creation.
# To change this use the 'metric collection' parameter of the layout
# ####################
# All stress calculations will be performed using the euclidian norm
# ####################
# Spring constant is set to  0.5
# Damping constant is set to 0
# Spring constant scaling factor is set to 0.041666666666666664
# ####################
#  n sample -1: 10
#  n_neigh -1  0
# ####################
# The algorithm will use a random initialization for the low D embedding/layout
# ####################
# A 2D layout of the "rna N3k" dataset will be created
# using the "Chalmers' 1996" algorithm
# ####################
# The HD distance measure used is: euclidean
# ####################
# ####################
# No metrics will be collected during layout creation.
# To change this use the 'metric collection' parameter of the layout
# ####################
# All stress calculations will be performed using the euclidian norm
# ####################
# Spring constant is set to  0.5
# Damping constant is set to 0
# Spring constant scaling factor is set to 0.041666666666666664
# ####################
#  n sample -1: 10
#  n_neigh -1  0
# ####################
# The algorithm will use a random initialization for the low D embedding/layout
# ####################
# A 2D layout of the "rna N3k" dataset will be created
# using the "Chalmers' 1996" algorithm
# ####################
# The HD distance measure used is: euclidean
# ####################
# ####################
# No metrics will be collected during layout creation.
# To change this use the 'metric collection' parameter of the layout
# ####################
# All stress calculations will be performed using the euclidian norm
# ####################
# Spring constant is set to  0.5
# Damping constant is set to 0
# Spring constant scaling factor is set to 0.041666666666666664
# ####################
#  n sample: 12
#  n_neigh 1
#  n sample -1: 11
#  n_neigh -1  0
# ####################
# The algorithm will use a random initialization for the low D embedding/layout
# ####################
# A 2D layout of the "rna N3k" dataset will be created
# using the "Chalmers' 1996" algorithm
# ####################
# The HD distance measure used is: euclidean
# ####################
# ####################
# No metrics will be collected during layout creation.
# To change this use the 'metric collection' parameter of the layout
# ####################
# All stress calculations will be performed using the euclidian norm
# ####################
# Spring constant is set to  0.5
# Damping constant is set to 0
# Spring constant scaling factor is set to 0.038461538461538464
# ####################
#  n sample -1: 11
#  n_neigh -1  0
# ####################
# The algorithm will use a random initialization for the low D embedding/layout
# ####################
# A 2D layout of the "rna N3k" dataset will be created
# using the "Chalmers' 1996" algorithm
# ####################
# The HD distance measure used is: euclidean
# ####################
# ####################
# No metrics will be collected during layout creation.
# To change this use the 'metric collection' parameter of the layout
# ####################
# All stress calculations will be performed using the euclidian norm
# ####################
# Spring constant is set to  0.5
# Damping constant is set to 0
# Spring constant scaling factor is set to 0.038461538461538464
# ####################
#  n sample -1: 11
#  n_neigh -1  0
# ####################
# The algorithm will use a random initialization for the low D embedding/layout
# ####################
# A 2D layout of the "rna N3k" dataset will be created
# using the "Chalmers' 1996" algorithm
# ####################
# The HD distance measure used is: euclidean
# ####################
# ####################
# No metrics will be collected during layout creation.
# To change this use the 'metric collection' parameter of the layout
# ####################
# All stress calculations will be performed using the euclidian norm
# ####################
# Spring constant is set to  0.5
# Damping constant is set to 0
# Spring constant scaling factor is set to 0.038461538461538464
# ####################
#  n sample: 13
#  n_neigh 1
#  n sample -1: 12
#  n_neigh -1  0
# ####################
# The algorithm will use a random initialization for the low D embedding/layout
# ####################
# A 2D layout of the "rna N3k" dataset will be created
# using the "Chalmers' 1996" algorithm
# ####################
# The HD distance measure used is: euclidean
# ####################
# ####################
# No metrics will be collected during layout creation.
# To change this use the 'metric collection' parameter of the layout
# ####################
# All stress calculations will be performed using the euclidian norm
# ####################
# Spring constant is set to  0.5
# Damping constant is set to 0
# Spring constant scaling factor is set to 0.03571428571428571
# ####################
#  n sample -1: 12
#  n_neigh -1  0
# ####################
# The algorithm will use a random initialization for the low D embedding/layout
# ####################
# A 2D layout of the "rna N3k" dataset will be created
# using the "Chalmers' 1996" algorithm
# ####################
# The HD distance measure used is: euclidean
# ####################
# ####################
# No metrics will be collected during layout creation.
# To change this use the 'metric collection' parameter of the layout
# ####################
# All stress calculations will be performed using the euclidian norm
# ####################
# Spring constant is set to  0.5
# Damping constant is set to 0
# Spring constant scaling factor is set to 0.03571428571428571
# ####################
#  n sample -1: 12
#  n_neigh -1  0
# ####################
# The algorithm will use a random initialization for the low D embedding/layout
# ####################
# A 2D layout of the "rna N3k" dataset will be created
# using the "Chalmers' 1996" algorithm
# ####################
# The HD distance measure used is: euclidean
# ####################
# ####################
# No metrics will be collected during layout creation.
# To change this use the 'metric collection' parameter of the layout
# ####################
# All stress calculations will be performed using the euclidian norm
# ####################
# Spring constant is set to  0.5
# Damping constant is set to 0
# Spring constant scaling factor is set to 0.03571428571428571
# ####################
#  n sample: 14
#  n_neigh 1
#  n sample -1: 13
#  n_neigh -1  0
# ####################
# The algorithm will use a random initialization for the low D embedding/layout
# ####################
# A 2D layout of the "rna N3k" dataset will be created
# using the "Chalmers' 1996" algorithm
# ####################
# The HD distance measure used is: euclidean
# ####################
# ####################
# No metrics will be collected during layout creation.
# To change this use the 'metric collection' parameter of the layout
# ####################
# All stress calculations will be performed using the euclidian norm
# ####################
# Spring constant is set to  0.5
# Damping constant is set to 0
# Spring constant scaling factor is set to 0.03333333333333333
# ####################
#  n sample -1: 13
#  n_neigh -1  0
# ####################
# The algorithm will use a random initialization for the low D embedding/layout
# ####################
# A 2D layout of the "rna N3k" dataset will be created
# using the "Chalmers' 1996" algorithm
# ####################
# The HD distance measure used is: euclidean
# ####################
# ####################
# No metrics will be collected during layout creation.
# To change this use the 'metric collection' parameter of the layout
# ####################
# All stress calculations will be performed using the euclidian norm
# ####################
# Spring constant is set to  0.5
# Damping constant is set to 0
# Spring constant scaling factor is set to 0.03333333333333333
# ####################
#  n sample -1: 13
#  n_neigh -1  0
# ####################
# The algorithm will use a random initialization for the low D embedding/layout
# ####################
# A 2D layout of the "rna N3k" dataset will be created
# using the "Chalmers' 1996" algorithm
# ####################
# The HD distance measure used is: euclidean
# ####################
# ####################
# No metrics will be collected during layout creation.
# To change this use the 'metric collection' parameter of the layout
# ####################
# All stress calculations will be performed using the euclidian norm
# ####################
# Spring constant is set to  0.5
# Damping constant is set to 0
# Spring constant scaling factor is set to 0.03333333333333333
# ####################
#  n sample: 15
#  n_neigh 1
#  n sample -1: 14
#  n_neigh -1  0
# ####################
# The algorithm will use a random initialization for the low D embedding/layout
# ####################
# A 2D layout of the "rna N3k" dataset will be created
# using the "Chalmers' 1996" algorithm
# ####################
# The HD distance measure used is: euclidean
# ####################
# ####################
# No metrics will be collected during layout creation.
# To change this use the 'metric collection' parameter of the layout
# ####################
# All stress calculations will be performed using the euclidian norm
# ####################
# Spring constant is set to  0.5
# Damping constant is set to 0
# Spring constant scaling factor is set to 0.03125
# ####################
#  n sample -1: 14
#  n_neigh -1  0
# ####################
# The algorithm will use a random initialization for the low D embedding/layout
# ####################
# A 2D layout of the "rna N3k" dataset will be created
# using the "Chalmers' 1996" algorithm
# ####################
# The HD distance measure used is: euclidean
# ####################
# ####################
# No metrics will be collected during layout creation.
# To change this use the 'metric collection' parameter of the layout
# ####################
# All stress calculations will be performed using the euclidian norm
# ####################
# Spring constant is set to  0.5
# Damping constant is set to 0
# Spring constant scaling factor is set to 0.03125
# ####################
#  n sample -1: 14
#  n_neigh -1  0
# ####################
# The algorithm will use a random initialization for the low D embedding/layout
# ####################
# A 2D layout of the "rna N3k" dataset will be created
# using the "Chalmers' 1996" algorithm
# ####################
# The HD distance measure used is: euclidean
# ####################
# ####################
# No metrics will be collected during layout creation.
# To change this use the 'metric collection' parameter of the layout
# ####################
# All stress calculations will be performed using the euclidian norm
# ####################
# Spring constant is set to  0.5
# Damping constant is set to 0
# Spring constant scaling factor is set to 0.03125
# ####################
#  n sample: 16
#  n_neigh 1
#  n sample -1: 15
#  n_neigh -1  0
# ####################
# The algorithm will use a random initialization for the low D embedding/layout
# ####################
# A 2D layout of the "rna N3k" dataset will be created
# using the "Chalmers' 1996" algorithm
# ####################
# The HD distance measure used is: euclidean
# ####################
# ####################
# No metrics will be collected during layout creation.
# To change this use the 'metric collection' parameter of the layout
# ####################
# All stress calculations will be performed using the euclidian norm
# ####################
# Spring constant is set to  0.5
# Damping constant is set to 0
# Spring constant scaling factor is set to 0.029411764705882353
# ####################
#  n sample -1: 15
#  n_neigh -1  0
# ####################
# The algorithm will use a random initialization for the low D embedding/layout
# ####################
# A 2D layout of the "rna N3k" dataset will be created
# using the "Chalmers' 1996" algorithm
# ####################
# The HD distance measure used is: euclidean
# ####################
# ####################
# No metrics will be collected during layout creation.
# To change this use the 'metric collection' parameter of the layout
# ####################
# All stress calculations will be performed using the euclidian norm
# ####################
# Spring constant is set to  0.5
# Damping constant is set to 0
# Spring constant scaling factor is set to 0.029411764705882353
# ####################
#  n sample -1: 15
#  n_neigh -1  0
# ####################
# The algorithm will use a random initialization for the low D embedding/layout
# ####################
# A 2D layout of the "rna N3k" dataset will be created
# using the "Chalmers' 1996" algorithm
# ####################
# The HD distance measure used is: euclidean
# ####################
# ####################
# No metrics will be collected during layout creation.
# To change this use the 'metric collection' parameter of the layout
# ####################
# All stress calculations will be performed using the euclidian norm
# ####################
# Spring constant is set to  0.5
# Damping constant is set to 0
# Spring constant scaling factor is set to 0.029411764705882353
# ####################
#  n sample: 17
#  n_neigh 1
#  n sample -1: 16
#  n_neigh -1  0
# ####################
# The algorithm will use a random initialization for the low D embedding/layout
# ####################
# A 2D layout of the "rna N3k" dataset will be created
# using the "Chalmers' 1996" algorithm
# ####################
# The HD distance measure used is: euclidean
# ####################
# ####################
# No metrics will be collected during layout creation.
# To change this use the 'metric collection' parameter of the layout
# ####################
# All stress calculations will be performed using the euclidian norm
# ####################
# Spring constant is set to  0.5
# Damping constant is set to 0
# Spring constant scaling factor is set to 0.027777777777777776
# ####################
#  n sample -1: 16
#  n_neigh -1  0
# ####################
# The algorithm will use a random initialization for the low D embedding/layout
# ####################
# A 2D layout of the "rna N3k" dataset will be created
# using the "Chalmers' 1996" algorithm
# ####################
# The HD distance measure used is: euclidean
# ####################
# ####################
# No metrics will be collected during layout creation.
# To change this use the 'metric collection' parameter of the layout
# ####################
# All stress calculations will be performed using the euclidian norm
# ####################
# Spring constant is set to  0.5
# Damping constant is set to 0
# Spring constant scaling factor is set to 0.027777777777777776
# ####################
#  n sample -1: 16
#  n_neigh -1  0
# ####################
# The algorithm will use a random initialization for the low D embedding/layout
# ####################
# A 2D layout of the "rna N3k" dataset will be created
# using the "Chalmers' 1996" algorithm
# ####################
# The HD distance measure used is: euclidean
# ####################
# ####################
# No metrics will be collected during layout creation.
# To change this use the 'metric collection' parameter of the layout
# ####################
# All stress calculations will be performed using the euclidian norm
# ####################
# Spring constant is set to  0.5
# Damping constant is set to 0
# Spring constant scaling factor is set to 0.027777777777777776
# ####################
#  n sample: 18
#  n_neigh 1
#  n sample -1: 17
#  n_neigh -1  0
# ####################
# The algorithm will use a random initialization for the low D embedding/layout
# ####################
# A 2D layout of the "rna N3k" dataset will be created
# using the "Chalmers' 1996" algorithm
# ####################
# The HD distance measure used is: euclidean
# ####################
# ####################
# No metrics will be collected during layout creation.
# To change this use the 'metric collection' parameter of the layout
# ####################
# All stress calculations will be performed using the euclidian norm
# ####################
# Spring constant is set to  0.5
# Damping constant is set to 0
# Spring constant scaling factor is set to 0.02631578947368421
# ####################
#  n sample -1: 17
#  n_neigh -1  0
# ####################
# The algorithm will use a random initialization for the low D embedding/layout
# ####################
# A 2D layout of the "rna N3k" dataset will be created
# using the "Chalmers' 1996" algorithm
# ####################
# The HD distance measure used is: euclidean
# ####################
# ####################
# No metrics will be collected during layout creation.
# To change this use the 'metric collection' parameter of the layout
# ####################
# All stress calculations will be performed using the euclidian norm
# ####################
# Spring constant is set to  0.5
# Damping constant is set to 0
# Spring constant scaling factor is set to 0.02631578947368421
# ####################
#  n sample -1: 17
#  n_neigh -1  0
# ####################
# The algorithm will use a random initialization for the low D embedding/layout
# ####################
# A 2D layout of the "rna N3k" dataset will be created
# using the "Chalmers' 1996" algorithm
# ####################
# The HD distance measure used is: euclidean
# ####################
# ####################
# No metrics will be collected during layout creation.
# To change this use the 'metric collection' parameter of the layout
# ####################
# All stress calculations will be performed using the euclidian norm
# ####################
# Spring constant is set to  0.5
# Damping constant is set to 0
# Spring constant scaling factor is set to 0.02631578947368421
# ####################
#  n sample: 19
#  n_neigh 1
#  n sample -1: 18
#  n_neigh -1  0
# ####################
# The algorithm will use a random initialization for the low D embedding/layout
# ####################
# A 2D layout of the "rna N3k" dataset will be created
# using the "Chalmers' 1996" algorithm
# ####################
# The HD distance measure used is: euclidean
# ####################
# ####################
# No metrics will be collected during layout creation.
# To change this use the 'metric collection' parameter of the layout
# ####################
# All stress calculations will be performed using the euclidian norm
# ####################
# Spring constant is set to  0.5
# Damping constant is set to 0
# Spring constant scaling factor is set to 0.025
# ####################
#  n sample -1: 18
#  n_neigh -1  0
# ####################
# The algorithm will use a random initialization for the low D embedding/layout
# ####################
# A 2D layout of the "rna N3k" dataset will be created
# using the "Chalmers' 1996" algorithm
# ####################
# The HD distance measure used is: euclidean
# ####################
# ####################
# No metrics will be collected during layout creation.
# To change this use the 'metric collection' parameter of the layout
# ####################
# All stress calculations will be performed using the euclidian norm
# ####################
# Spring constant is set to  0.5
# Damping constant is set to 0
# Spring constant scaling factor is set to 0.025
# ####################
#  n sample -1: 18
#  n_neigh -1  0
# ####################
# The algorithm will use a random initialization for the low D embedding/layout
# ####################
# A 2D layout of the "rna N3k" dataset will be created
# using the "Chalmers' 1996" algorithm
# ####################
# The HD distance measure used is: euclidean
# ####################
# ####################
# No metrics will be collected during layout creation.
# To change this use the 'metric collection' parameter of the layout
# ####################
# All stress calculations will be performed using the euclidian norm
# ####################
# Spring constant is set to  0.5
# Damping constant is set to 0
# Spring constant scaling factor is set to 0.025
# ####################
#  n sample: 20
#  n_neigh 1
#  n sample -1: 19
#  n_neigh -1  0
# ####################
# The algorithm will use a random initialization for the low D embedding/layout
# ####################
# A 2D layout of the "rna N3k" dataset will be created
# using the "Chalmers' 1996" algorithm
# ####################
# The HD distance measure used is: euclidean
# ####################
# ####################
# No metrics will be collected during layout creation.
# To change this use the 'metric collection' parameter of the layout
# ####################
# All stress calculations will be performed using the euclidian norm
# ####################
# Spring constant is set to  0.5
# Damping constant is set to 0
# Spring constant scaling factor is set to 0.023809523809523808
# ####################
#  n sample -1: 19
#  n_neigh -1  0
# ####################
# The algorithm will use a random initialization for the low D embedding/layout
# ####################
# A 2D layout of the "rna N3k" dataset will be created
# using the "Chalmers' 1996" algorithm
# ####################
# The HD distance measure used is: euclidean
# ####################
# ####################
# No metrics will be collected during layout creation.
# To change this use the 'metric collection' parameter of the layout
# ####################
# All stress calculations will be performed using the euclidian norm
# ####################
# Spring constant is set to  0.5
# Damping constant is set to 0
# Spring constant scaling factor is set to 0.023809523809523808
# ####################
#  n sample -1: 19
#  n_neigh -1  0
# ####################
# The algorithm will use a random initialization for the low D embedding/layout
# ####################
# A 2D layout of the "rna N3k" dataset will be created
# using the "Chalmers' 1996" algorithm
# ####################
# The HD distance measure used is: euclidean
# ####################
# ####################
# No metrics will be collected during layout creation.
# To change this use the 'metric collection' parameter of the layout
# ####################
# All stress calculations will be performed using the euclidian norm
# ####################
# Spring constant is set to  0.5
# Damping constant is set to 0
# Spring constant scaling factor is set to 0.023809523809523808
# ####################
#  n sample: 1
#  n_neigh 2
#  n sample -1: 0
#  n_neigh -1  1
# ####################
# The algorithm will use a random initialization for the low D embedding/layout
# ####################
# A 2D layout of the "rna N3k" dataset will be created
# using the "Chalmers' 1996" algorithm
# ####################
# The HD distance measure used is: euclidean
# ####################
# ####################
# No metrics will be collected during layout creation.
# To change this use the 'metric collection' parameter of the layout
# ####################
# All stress calculations will be performed using the euclidian norm
# ####################
# Spring constant is set to  0.5
# Damping constant is set to 0
# Spring constant scaling factor is set to 0.16666666666666666
# ####################
#  n sample -1: 0
#  n_neigh -1  1
# ####################
# The algorithm will use a random initialization for the low D embedding/layout
# ####################
# A 2D layout of the "rna N3k" dataset will be created
# using the "Chalmers' 1996" algorithm
# ####################
# The HD distance measure used is: euclidean
# ####################
# ####################
# No metrics will be collected during layout creation.
# To change this use the 'metric collection' parameter of the layout
# ####################
# All stress calculations will be performed using the euclidian norm
# ####################
# Spring constant is set to  0.5
# Damping constant is set to 0
# Spring constant scaling factor is set to 0.16666666666666666
# ####################
#  n sample -1: 0
#  n_neigh -1  1
# ####################
# The algorithm will use a random initialization for the low D embedding/layout
# ####################
# A 2D layout of the "rna N3k" dataset will be created
# using the "Chalmers' 1996" algorithm
# ####################
# The HD distance measure used is: euclidean
# ####################
# ####################
# No metrics will be collected during layout creation.
# To change this use the 'metric collection' parameter of the layout
# ####################
# All stress calculations will be performed using the euclidian norm
# ####################
# Spring constant is set to  0.5
# Damping constant is set to 0
# Spring constant scaling factor is set to 0.16666666666666666
# ####################
#  n sample: 2
#  n_neigh 2
#  n sample -1: 1
#  n_neigh -1  1
# ####################
# The algorithm will use a random initialization for the low D embedding/layout
# ####################
# A 2D layout of the "rna N3k" dataset will be created
# using the "Chalmers' 1996" algorithm
# ####################
# The HD distance measure used is: euclidean
# ####################
# ####################
# No metrics will be collected during layout creation.
# To change this use the 'metric collection' parameter of the layout
# ####################
# All stress calculations will be performed using the euclidian norm
# ####################
# Spring constant is set to  0.5
# Damping constant is set to 0
# Spring constant scaling factor is set to 0.125
# ####################
#  n sample -1: 1
#  n_neigh -1  1
# ####################
# The algorithm will use a random initialization for the low D embedding/layout
# ####################
# A 2D layout of the "rna N3k" dataset will be created
# using the "Chalmers' 1996" algorithm
# ####################
# The HD distance measure used is: euclidean
# ####################
# ####################
# No metrics will be collected during layout creation.
# To change this use the 'metric collection' parameter of the layout
# ####################
# All stress calculations will be performed using the euclidian norm
# ####################
# Spring constant is set to  0.5
# Damping constant is set to 0
# Spring constant scaling factor is set to 0.125
# ####################
#  n sample -1: 1
#  n_neigh -1  1
# ####################
# The algorithm will use a random initialization for the low D embedding/layout
# ####################
# A 2D layout of the "rna N3k" dataset will be created
# using the "Chalmers' 1996" algorithm
# ####################
# The HD distance measure used is: euclidean
# ####################
# ####################
# No metrics will be collected during layout creation.
# To change this use the 'metric collection' parameter of the layout
# ####################
# All stress calculations will be performed using the euclidian norm
# ####################
# Spring constant is set to  0.5
# Damping constant is set to 0
# ...
# ####################
# All stress calculations will be performed using the euclidian norm
# ####################
# Spring constant is set to  0.5
# Damping constant is set to 0
# Spring constant scaling factor is set to 0.029411764705882353
# ####################
#  n sample: 12
#  n_neigh 6
#  n sample -1: 11
#  n_neigh -1  5
# ####################
# The algorithm will use a random initialization for the low D embedding/layout
# ####################
# A 2D layout of the "rna N3k" dataset will be created
# using the "Chalmers' 1996" algorithm
# ####################
# The HD distance measure used is: euclidean
# ####################
# ####################
# No metrics will be collected during layout creation.
# To change this use the 'metric collection' parameter of the layout
# ####################
# All stress calculations will be performed using the euclidian norm
# ####################
# Spring constant is set to  0.5
# Damping constant is set to 0
# Spring constant scaling factor is set to 0.027777777777777776
# ####################
#  n sample -1: 11
#  n_neigh -1  5
# ####################
# The algorithm will use a random initialization for the low D embedding/layout
# ####################
# A 2D layout of the "rna N3k" dataset will be created
# using the "Chalmers' 1996" algorithm
# ####################
# The HD distance measure used is: euclidean
# ####################
# ####################
# No metrics will be collected during layout creation.
# To change this use the 'metric collection' parameter of the layout
# ####################
# All stress calculations will be performed using the euclidian norm
# ####################
# Spring constant is set to  0.5
# Damping constant is set to 0
# Spring constant scaling factor is set to 0.027777777777777776
# ####################
#  n sample -1: 11
#  n_neigh -1  5
# ####################
# The algorithm will use a random initialization for the low D embedding/layout
# ####################
# A 2D layout of the "rna N3k" dataset will be created
# using the "Chalmers' 1996" algorithm
# ####################
# The HD distance measure used is: euclidean
# ####################
# ####################
# No metrics will be collected during layout creation.
# To change this use the 'metric collection' parameter of the layout
# ####################
# All stress calculations will be performed using the euclidian norm
# ####################
# Spring constant is set to  0.5
# Damping constant is set to 0
# Spring constant scaling factor is set to 0.027777777777777776
# ####################
#  n sample: 13
#  n_neigh 6
#  n sample -1: 12
#  n_neigh -1  5
# ####################
# The algorithm will use a random initialization for the low D embedding/layout
# ####################
# A 2D layout of the "rna N3k" dataset will be created
# using the "Chalmers' 1996" algorithm
# ####################
# The HD distance measure used is: euclidean
# ####################
# ####################
# No metrics will be collected during layout creation.
# To change this use the 'metric collection' parameter of the layout
# ####################
# All stress calculations will be performed using the euclidian norm
# ####################
# Spring constant is set to  0.5
# Damping constant is set to 0
# Spring constant scaling factor is set to 0.02631578947368421
# ####################
#  n sample -1: 12
#  n_neigh -1  5
# ####################
# The algorithm will use a random initialization for the low D embedding/layout
# ####################
# A 2D layout of the "rna N3k" dataset will be created
# using the "Chalmers' 1996" algorithm
# ####################
# The HD distance measure used is: euclidean
# ####################
# ####################
# No metrics will be collected during layout creation.
# To change this use the 'metric collection' parameter of the layout
# ####################
# All stress calculations will be performed using the euclidian norm
# ####################
# Spring constant is set to  0.5
# Damping constant is set to 0
# Spring constant scaling factor is set to 0.02631578947368421
# ####################
#  n sample -1: 12
#  n_neigh -1  5
# ####################
# The algorithm will use a random initialization for the low D embedding/layout
# ####################
# A 2D layout of the "rna N3k" dataset will be created
# using the "Chalmers' 1996" algorithm
# ####################
# The HD distance measure used is: euclidean
# ####################
# ####################
# No metrics will be collected during layout creation.
# To change this use the 'metric collection' parameter of the layout
# ####################
# All stress calculations will be performed using the euclidian norm
# ####################
# Spring constant is set to  0.5
# Damping constant is set to 0
# Spring constant scaling factor is set to 0.02631578947368421
# ####################
#  n sample: 14
#  n_neigh 6
#  n sample -1: 13
#  n_neigh -1  5
# ####################
# The algorithm will use a random initialization for the low D embedding/layout
# ####################
# A 2D layout of the "rna N3k" dataset will be created
# using the "Chalmers' 1996" algorithm
# ####################
# The HD distance measure used is: euclidean
# ####################
# ####################
# No metrics will be collected during layout creation.
# To change this use the 'metric collection' parameter of the layout
# ####################
# All stress calculations will be performed using the euclidian norm
# ####################
# Spring constant is set to  0.5
# Damping constant is set to 0
# Spring constant scaling factor is set to 0.025
# ####################
#  n sample -1: 13
#  n_neigh -1  5
# ####################
# The algorithm will use a random initialization for the low D embedding/layout
# ####################
# A 2D layout of the "rna N3k" dataset will be created
# using the "Chalmers' 1996" algorithm
# ####################
# The HD distance measure used is: euclidean
# ####################
# ####################
# No metrics will be collected during layout creation.
# To change this use the 'metric collection' parameter of the layout
# ####################
# All stress calculations will be performed using the euclidian norm
# ####################
# Spring constant is set to  0.5
# Damping constant is set to 0
# Spring constant scaling factor is set to 0.025
# ####################
#  n sample -1: 13
#  n_neigh -1  5
# ####################
# The algorithm will use a random initialization for the low D embedding/layout
# ####################
# A 2D layout of the "rna N3k" dataset will be created
# using the "Chalmers' 1996" algorithm
# ####################
# The HD distance measure used is: euclidean
# ####################
# ####################
# No metrics will be collected during layout creation.
# To change this use the 'metric collection' parameter of the layout
# ####################
# All stress calculations will be performed using the euclidian norm
# ####################
# Spring constant is set to  0.5
# Damping constant is set to 0
# Spring constant scaling factor is set to 0.025
# ####################
#  n sample: 15
#  n_neigh 6
#  n sample -1: 14
#  n_neigh -1  5
# ####################
# The algorithm will use a random initialization for the low D embedding/layout
# ####################
# A 2D layout of the "rna N3k" dataset will be created
# using the "Chalmers' 1996" algorithm
# ####################
# The HD distance measure used is: euclidean
# ####################
# ####################
# No metrics will be collected during layout creation.
# To change this use the 'metric collection' parameter of the layout
# ####################
# All stress calculations will be performed using the euclidian norm
# ####################
# Spring constant is set to  0.5
# Damping constant is set to 0
# Spring constant scaling factor is set to 0.023809523809523808
# ####################
#  n sample -1: 14
#  n_neigh -1  5
# ####################
# The algorithm will use a random initialization for the low D embedding/layout
# ####################
# A 2D layout of the "rna N3k" dataset will be created
# using the "Chalmers' 1996" algorithm
# ####################
# The HD distance measure used is: euclidean
# ####################
# ####################
# No metrics will be collected during layout creation.
# To change this use the 'metric collection' parameter of the layout
# ####################
# All stress calculations will be performed using the euclidian norm
# ####################
# Spring constant is set to  0.5
# Damping constant is set to 0
# Spring constant scaling factor is set to 0.023809523809523808
# ####################
#  n sample -1: 14
#  n_neigh -1  5
# ####################
# The algorithm will use a random initialization for the low D embedding/layout
# ####################
# A 2D layout of the "rna N3k" dataset will be created
# using the "Chalmers' 1996" algorithm
# ####################
# The HD distance measure used is: euclidean
# ####################
# ####################
# No metrics will be collected during layout creation.
# To change this use the 'metric collection' parameter of the layout
# ####################
# All stress calculations will be performed using the euclidian norm
# ####################
# Spring constant is set to  0.5
# Damping constant is set to 0
# Spring constant scaling factor is set to 0.023809523809523808
# ####################
#  n sample: 16
#  n_neigh 6
#  n sample -1: 15
#  n_neigh -1  5
# ####################
# The algorithm will use a random initialization for the low D embedding/layout
# ####################
# A 2D layout of the "rna N3k" dataset will be created
# using the "Chalmers' 1996" algorithm
# ####################
# The HD distance measure used is: euclidean
# ####################
# ####################
# No metrics will be collected during layout creation.
# To change this use the 'metric collection' parameter of the layout
# ####################
# All stress calculations will be performed using the euclidian norm
# ####################
# Spring constant is set to  0.5
# Damping constant is set to 0
# Spring constant scaling factor is set to 0.022727272727272728
# ####################
#  n sample -1: 15
#  n_neigh -1  5
# ####################
# The algorithm will use a random initialization for the low D embedding/layout
# ####################
# A 2D layout of the "rna N3k" dataset will be created
# using the "Chalmers' 1996" algorithm
# ####################
# The HD distance measure used is: euclidean
# ####################
# ####################
# No metrics will be collected during layout creation.
# To change this use the 'metric collection' parameter of the layout
# ####################
# All stress calculations will be performed using the euclidian norm
# ####################
# Spring constant is set to  0.5
# Damping constant is set to 0
# Spring constant scaling factor is set to 0.022727272727272728
# ####################
#  n sample -1: 15
#  n_neigh -1  5
# ####################
# The algorithm will use a random initialization for the low D embedding/layout
# ####################
# A 2D layout of the "rna N3k" dataset will be created
# using the "Chalmers' 1996" algorithm
# ####################
# The HD distance measure used is: euclidean
# ####################
# ####################
# No metrics will be collected during layout creation.
# To change this use the 'metric collection' parameter of the layout
# ####################
# All stress calculations will be performed using the euclidian norm
# ####################
# Spring constant is set to  0.5
# Damping constant is set to 0
# Spring constant scaling factor is set to 0.022727272727272728
# ####################
#  n sample: 17
#  n_neigh 6
#  n sample -1: 16
#  n_neigh -1  5
# ####################
# The algorithm will use a random initialization for the low D embedding/layout
# ####################
# A 2D layout of the "rna N3k" dataset will be created
# using the "Chalmers' 1996" algorithm
# ####################
# The HD distance measure used is: euclidean
# ####################
# ####################
# No metrics will be collected during layout creation.
# To change this use the 'metric collection' parameter of the layout
# ####################
# All stress calculations will be performed using the euclidian norm
# ####################
# Spring constant is set to  0.5
# Damping constant is set to 0
# Spring constant scaling factor is set to 0.021739130434782608
# ####################
#  n sample -1: 16
#  n_neigh -1  5
# ####################
# The algorithm will use a random initialization for the low D embedding/layout
# ####################
# A 2D layout of the "rna N3k" dataset will be created
# using the "Chalmers' 1996" algorithm
# ####################
# The HD distance measure used is: euclidean
# ####################
# ####################
# No metrics will be collected during layout creation.
# To change this use the 'metric collection' parameter of the layout
# ####################
# All stress calculations will be performed using the euclidian norm
# ####################
# Spring constant is set to  0.5
# Damping constant is set to 0
# Spring constant scaling factor is set to 0.021739130434782608
# ####################
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 22
#      18 algo96 = Chalmers96(dataset=dataset, distance_fn=euclidean,
#      19                 damping_constant=0, spring_constant=0.5,
#      20                 use_knnd=False, sample_set_size=n_neigh, neighbour_set_size=n_sample)
#      21 start = perf_counter()
# ---> 22 layout = LayoutCreation.create_layout(algo96, no_iters=100)
#      23 results[dataset_names[i]][0][n_neigh-1, n_sample-1, j] = perf_counter() - start
#      24 results[dataset_names[i]][1][n_neigh-1][ n_sample-1][ j] = layout
#
# File ~\Desktop\2095736w\hdimvis\create_low_d_layout\LayoutCreation.py:92, in LayoutCreation.create_layout(algorithm, no_iters, optional_metric_collection, **additional_parameters)
#      89     print(f"Spring constant scaling factor is set to {layout.algorithm.sc_scaling_factor} ")
#      90     print("#" * 20)
# ---> 92 layout.run()
#      93 return layout
#
# File ~\Desktop\2095736w\hdimvis\create_low_d_layout\Chalmers96Layout.py:38, in Chalmers96Layout.run(self)
#      36 if self.optional_metric_collection is not None:
#      37     self.collect_metrics()
# ---> 38 self.algorithm.one_iteration(self.alpha)
#      39 self.iteration_number += 1
#      40 self.final_positions = self.algorithm.get_positions()
#
# File ~\Desktop\2095736w\hdimvis\algorithms\spring_force_algos\chalmers96_algo\Chalmers96.py:45, in Chalmers96.one_iteration(self, alpha)
#      43 sample_set = self._get_sample_set(i)
#      44 for global_index in sample_set:
# ---> 45     self._set_position_update(source=self.nodes[i], target=self.nodes[global_index])
#      47     if not self.integrate_sum:  # integration step for each force in turn
#      48         for node in [self.nodes[i], self.nodes[global_index]]:
#
# File ~\Desktop\2095736w\hdimvis\algorithms\spring_force_algos\SpringForceBase.py:180, in SpringForceBase._set_position_update(self, source, target, cache_distance)
#     171 def _set_position_update(self, source: Node, target: Node,
#     172                          cache_distance: bool = False) -> None:
#     173     """
#     174     Calculate the force between two nodes and increment the position update
#     175     the integration timestep for force and mass of the "particle" are assumed to be 1,
#    (...)
#     178     We simply add all the forces on top of each other as we go
#     179     """
# --> 180     f_x, f_y = self._calculate_force(source, target,
#     181                                    cache_distance=cache_distance)
#     183     source.increment_position_update(f_x, f_y)
#     184     target.increment_position_update(-f_x, -f_y)
#
# File ~\Desktop\2095736w\hdimvis\algorithms\spring_force_algos\SpringForceBase.py:137, in SpringForceBase._calculate_force(self, source, target, cache_distance)
#     132 """
#     133 Calculate the spring force to apply between two nodes i and j
#     134 """
#     136 dist_x, dist_y = self._low_d_distances_xy(source, target) # x,y distance vector from source to target
# --> 137 ld_dist = math.hypot(dist_x, dist_y)
#     138 hd_dist = self.hd_distance(source, target, cache=cache_distance)
#     139 # if k%500 == 0:
#     140 # print(f"ld dist: {ld_dist}")
#     141 # print(f"hd dist: {hd_dist}")
#
# KeyboardInterrupt:
