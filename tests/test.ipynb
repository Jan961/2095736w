# %%
from hdimvis.data_fetchers.DataFetcher import DataFetcher
# %matplotlib notebook

# %%
globe = DataFetcher.fetch_data('globe', size=1000)
# Out:
# ####################
# Fetching the "globe" dataset
# <div id='820f098f-518d-45ff-b6a9-3091ca5b4dd9'></div>
# <div id='015d5bd8-fc55-48c4-be19-c93b2a43bf36'></div>
# <div id='3da85d48-bddf-419c-9a78-e9a65e3eb9fa'></div>
# <div id='25cb7e87-d5ca-405d-9935-f311ffed17a2'></div>
# <div id='e02c68b5-8bde-4614-b6f1-ad091a60f842'></div>
# <div id='7f7463d4-d4c6-4f57-80f0-b0ed5213e2fb'></div>
#  concat[[474. 719.   1.]
#  [439. 922.   1.]
#  [543. 781.   1.]
#  [383. 918.   1.]
#  [324. 949.   1.]
#  [513. 846.   1.]
#  [445. 718.   1.]
#  [473. 905.   1.]
#  [466. 792.   1.]
#  [480. 894.   1.]
#  [370. 887.   1.]
#  [427. 926.   1.]
#  [315. 896.   1.]
#  [424. 734.   1.]
#  [456. 805.   1.]
#  [283. 894.   1.]
#  [376. 860.   1.]
#  [459. 858.   1.]
#  [462. 736.   1.]
#  [369. 915.   1.]
#  [520. 914.   1.]
#  [476. 761.   1.]
#  [391. 853.   1.]
#  [452. 778.   1.]
#  [493. 861.   1.]
#  [454. 785.   1.]
#  [335. 939.   1.]
#  [456. 906.   1.]
#  [376. 897.   1.]
#  [475. 738.   1.]
# ...
