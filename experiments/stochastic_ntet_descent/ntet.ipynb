# %%
from experiments.cube.Cube import Cube
from hdimvis.algorithms.stochastic_ntet_algo.SNaD import SNaD
from hdimvis.create_low_d_layout.LowDLayoutCreation import LowDLayoutCreation
from hdimvis.metrics.stress.stress import vectorised_stress
from hdimvis.metrics.distance_measures.euclidian_and_manhattan import euclidean

# %%
cube = Cube(num_points=100, side=30, angle=0.4)
dataset= cube.get_sample_dataset(2000)

# %%
ntets= [2, 3, 4, 6, 8, 10, 12, 20, 50]

for i in ntets:
    snad = SNaD(dataset=dataset, ntet_size=i)
    layout_snad = LowDLayoutCreation().create_layout(snad, no_iters=1000, optional_metric_collection=None)
    stress = vectorised_stress(dataset.data, layout_snad.get_final_positions(), euclidean)
    cube.plot_2d(layout_snad, title=f"Snad embedding, n = {i}, stress: {stress:.3f},"
                                    f" average ntet stress: {snad.get_average_quartet_stress()}")
# Out:
# The algorithm will use a random initialization for the low D embedding/layout
# ####################
# A 2D layout of the "3d cube of 30^3 points - 2000 points sampled" dataset will be created
# using the "Stochastic Quartet Descent MDS" algorithm
# ####################
# The HD distance measure used is: euclidean
# ####################
# ####################
# No metrics will be collected during layout creation.
# To change this use the 'metric collection' parameter of the layout
# ####################
#  "N-tet" size: 2
# The algorithm will use a random initialization for the low D embedding/layout
# ####################
# A 2D layout of the "3d cube of 30^3 points - 2000 points sampled" dataset will be created
# using the "Stochastic Quartet Descent MDS" algorithm
# ####################
# The HD distance measure used is: euclidean
# ####################
# ####################
# No metrics will be collected during layout creation.
# To change this use the 'metric collection' parameter of the layout
# ####################
#  "N-tet" size: 3
# The algorithm will use a random initialization for the low D embedding/layout
# ####################
# A 2D layout of the "3d cube of 30^3 points - 2000 points sampled" dataset will be created
# using the "Stochastic Quartet Descent MDS" algorithm
# ####################
# The HD distance measure used is: euclidean
# ####################
# ####################
# No metrics will be collected during layout creation.
# To change this use the 'metric collection' parameter of the layout
# ####################
#  "N-tet" size: 4
# The algorithm will use a random initialization for the low D embedding/layout
# ####################
# A 2D layout of the "3d cube of 30^3 points - 2000 points sampled" dataset will be created
# using the "Stochastic Quartet Descent MDS" algorithm
# ####################
# The HD distance measure used is: euclidean
# ####################
# ####################
# No metrics will be collected during layout creation.
# To change this use the 'metric collection' parameter of the layout
# ####################
#  "N-tet" size: 6
# The algorithm will use a random initialization for the low D embedding/layout
# ####################
# A 2D layout of the "3d cube of 30^3 points - 2000 points sampled" dataset will be created
# using the "Stochastic Quartet Descent MDS" algorithm
# ####################
# The HD distance measure used is: euclidean
# ####################
# ####################
# No metrics will be collected during layout creation.
# To change this use the 'metric collection' parameter of the layout
# ####################
#  "N-tet" size: 8
# The algorithm will use a random initialization for the low D embedding/layout
# ####################
# A 2D layout of the "3d cube of 30^3 points - 2000 points sampled" dataset will be created
# using the "Stochastic Quartet Descent MDS" algorithm
# ####################
# The HD distance measure used is: euclidean
# ####################
# ####################
# No metrics will be collected during layout creation.
# To change this use the 'metric collection' parameter of the layout
# ####################
#  "N-tet" size: 10
# The algorithm will use a random initialization for the low D embedding/layout
# ####################
# A 2D layout of the "3d cube of 30^3 points - 2000 points sampled" dataset will be created
# using the "Stochastic Quartet Descent MDS" algorithm
# ####################
# The HD distance measure used is: euclidean
# ####################
# ####################
# No metrics will be collected during layout creation.
# To change this use the 'metric collection' parameter of the layout
# ####################
#  "N-tet" size: 12
# The algorithm will use a random initialization for the low D embedding/layout
# ####################
# A 2D layout of the "3d cube of 30^3 points - 2000 points sampled" dataset will be created
# using the "Stochastic Quartet Descent MDS" algorithm
# ####################
# The HD distance measure used is: euclidean
# ####################
# ####################
# No metrics will be collected during layout creation.
# To change this use the 'metric collection' parameter of the layout
# ####################
#  "N-tet" size: 20
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 5
#       3 for i in ntets:
#       4     snad = SQuaD(dataset=dataset, ntet_size=i)
# ----> 5     layout_snad = LowDLayoutCreation().create_layout(snad, no_iters=1000, optional_metric_collection=None)
#       6     stress = vectorised_stress(dataset.data, layout_snad.get_final_positions(), euclidean)
#       7     cube.plot_2d(layout_snad, title=f"Snad embedding, n = {i}, stress: {stress:.3f},"
#       8                                     f" average ntet stress: {snad.get_average_quartet_stress()}")
#
# File ~\Desktop\2095736w\hdimvis\create_low_d_layout\LowDLayoutCreation.py:68, in LowDLayoutCreation.create_layout(self, algorithm, no_iters, optional_metric_collection, **additional_parameters)
#      65 if isinstance(layout.algorithm, SpringForceBase):
#      66     layout.algorithm.build_nodes()
# ---> 68 layout.run()
#      69 return layout
#
# File ~\Desktop\2095736w\hdimvis\create_low_d_layout\SQuaDLayout.py:48, in SQuaDLayout.run(self)
#      45     self.LR *= decay
#      46     exaggerate_D = False
# ---> 48 self.algorithm.one_iteration(exaggerate_D, self.LR, calculate_quartet_stress)
#      49 if self.optional_metric_collection is not None:
#      50     self.collect_metrics()
#
# File ~\Desktop\2095736w\hdimvis\algorithms\stochastic_quartet_algo\SQuaD.py:68, in SQuaD.one_iteration(self, exaggerate_dist, LR, calculate_average_stress)
#      65 HD_points = self.data[quartet]
#      67 # HD distances between quartet points
# ---> 68 Dhd_quartet = compute_quartet_dhd(exaggerate_dist, HD_points, self.distance_fn)
#      70 # LD distances between quartet points and, including a full n_tet x n_tet sized matrix for grad computation
#      71 Dld_full_matrix, Dld_quartet = compute_quartet_dld(LD_points)
#
# File ~\Desktop\2095736w\hdimvis\algorithms\stochastic_quartet_algo\new_distance_calculations.py:5, in compute_quartet_dhd(exaggerate_dist, HD_points, distance_fn)
#       1 import numpy as np
# ----> 5 def compute_quartet_dhd(exaggerate_dist: bool, HD_points: np.ndarray, distance_fn):
#       7     Dhd_full_matrix = distance_fn(HD_points[:, :, None] - HD_points[:, :, None].T, 1)
#       9     if exaggerate_dist:     # during exaggeration: don't take the square root of the distances
#
# KeyboardInterrupt:
